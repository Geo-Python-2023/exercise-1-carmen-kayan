# %%
ice_cream_rating=8

# %%
sleeping_rating=7

# %%
first_name="Carmen"
last_name="Kayan"
my_name=(first_name+" "+last_name)
print(my_name)
# Out:
# Carmen Kayan

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2

# %%
print(happiness_rating)
# Out:
# 7.5

# %%
print(type(ice_cream_rating),type(sleeping_rating), type(happiness_rating))
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %% [markdown]
# the date types make sense

# %%
print("My name is",my_name,"and I give eating ice cream a score of",ice_cream_rating,"out of 10")
print("I am",first_name,"and my sleeping enjoyment rating is",sleeping_rating,"/ 10")
print("Based on the factors above, my happiness rating is",happiness_rating,"out of 10 or",happiness_rating*10.0,"%!")
# Out:
# My name is Carmen Kayan and I give eating ice cream a score of 8 out of 10
# I am Carmen and my sleeping enjoyment rating is 7 / 10
# Based on the factors above, my happiness rating is 7.5 out of 10 or 75.0 %!
